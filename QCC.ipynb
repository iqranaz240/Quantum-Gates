# %%
# %matplotlib inline
# Importing standard Qiskit libraries and configuring account
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *
# Loading your IBM Q account(s)
provider = IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2020-07-04 07:58:02,315: Credentials are already in use. The existing account in the session will be replaced.

# %%
from qiskit import*
from qiskit.visualization import plot_histogram
from qiskit.visualization import plot_bloch_multivector

# %%
qr = 5
qc = 5
n = 5
qc = QuantumCircuit(5,5)

for i in range (n):
    qc.measure(i, i)
qc.draw(output='mpl')

# %%
counts = execute(qc, Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, backend=simulator).result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j]

# %%
qr = 5
qc = 5
n = 5
qc1 = QuantumCircuit(5,5)
qc1.h(0)

for i in range (n):
    qc1.measure(i, i)
qc1.draw(output='mpl')

# %%
counts = execute(qc1, Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc1, backend=simulator).result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j]

# %%
qb = 5
cb = 5
qc2 = QuantumCircuit(qb, cb)
qc2.x(0)
for i in range (n):
    qc2.measure(i, i)
qc2.draw(output = 'mpl')

# %%
count = execute(qc2, Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(count)

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc2, backend=simulator).result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j]

# %%
qb = 5
cb = 5
qc3 = QuantumCircuit(qb, cb)
qc3.s(0)
for i in range (n):
    qc3.measure(i, i)
qc3.draw(output ='mpl')

# %%
counts = execute(qc3, Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc3, backend=simulator).result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j]

# %%
qb = 5
cb = 5
qc4 = QuantumCircuit(qb, cb)
qc4.sdg(0)
for i in range (n):
    qc4.measure(i, i)
qc4.draw(output ='mpl')

# %%
counts = execute(qc4, Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc4, backend=simulator).result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j]

# %%
qr = 5
qc = 5
n = 5
qc5 = QuantumCircuit(5,5)
qc5.y(0)

for i in range (n):
    qc5.measure(i, i)
qc5.draw(output='mpl')

# %%
counts = execute(qc5, Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc5, backend=simulator).result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [0.+0.j 0.+1.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j]

# %%
qr = 5
qc = 5
n = 5
qc6 = QuantumCircuit(5,5)
qc6.z(0)

for i in range (n):
    qc6.measure(i, i)
qc6.draw(output='mpl')

# %%
counts = execute(qc6, Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc6, backend=simulator).result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j]

# %%
qr = 5
qc = 5
n = 5
qc7 = QuantumCircuit(5,5)
qc7.h(0)
qc7.cx(0,1)

for i in range (n):
    qc7.measure(i, i)
qc7.draw(output='mpl')

# %%
counts = execute(qc7, Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc7, backend=simulator).result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j]

# %%
qr = 5
qc = 5
n = 5
qc8 = QuantumCircuit(5,5)
qc8.h(0)
qc8.ccx(0,1,2)

for i in range (n):
    qc8.measure(i, i)
qc8.draw(output='mpl')

# %%
counts = execute(qc8, Aer.get_backend('qasm_simulator')).result().get_counts()
plot_histogram(counts)

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc8, backend=simulator).result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j
#  0.+0.j 0.+0.j]
